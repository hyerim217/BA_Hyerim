# %%
import random
import scipy.stats as stats
import pandas as pd
import matplotlib.pyplot as plt
import numpy
from scipy.stats import multinomial
from scipy.stats import binom

from scipy.stats import poisson
import math

'''
The multinomial CDF function is the implementation of Levin's "Representaion of Multinomial Cumulative Distribution Function"

G:= Number of total groups (including non-protected)
k:= Position
p:= Array of probabilities of each group to be selected
tau_p:= Array of number of protected items

EXAMPLE:
Groups: ["White"(NP), "Black"(P), "Asian"(P), "Hispanic"(P)]
k: 30
p: [0.4, 0.3, 0.2, 0.1]
tau_p: [k, 10, 5, 3]
The ranking is fair if multinomCDF(4, 30, p, tau_p) > a = 0.1 
'''

def multinomCDF_log(G, k, p, tau_p):
    s = float(k);
    log_cdf = -poisson.logpmf(k,s);
    gamma1 = 0.0;
    gamma2 = 0.0;
    sum_s2 = 0.0;
    sum_mu = 0.0;
    
    # P(W=k)
    for i in range(0,G):
        sp = s*p[i];
        
        pcdf = poisson.cdf(tau_p[i],sp);
        log_cdf += numpy.log(pcdf);
        
        mu = sp*(1-poisson.pmf(tau_p[i],sp)/pcdf);
        s2 = mu-(tau_p[i]-mu)*(sp-mu);
        
        mr = tau_p[i];
        mf2 = sp*mu-mr*(sp-mu);
        
        mr *= tau_p[i]-1;
        mf3 = sp*mf2-mr*(sp-mu);
        
        mr *= tau_p[i]-2;
        mf4 = sp*mf3-mr*(sp-mu);
        
        mu2 = mf2+mu*(1-mu);
        mu3 = mf3+mf2*(3-3*mu)+mu*(1+mu*(-3+2*mu));
        mu4 = mf4+mf3*(6-4*mu)+mf2*(7+mu*(-12+6*mu))+mu*(1+mu*(-4+mu*(6-3*mu)));
        
        gamma1 += mu3;
        gamma2 += mu4-3*s2*s2;
        sum_mu += mu;
        sum_s2 += s2; 
    sp = numpy.sqrt(sum_s2);
    gamma1 /= sum_s2*sp;
    gamma2 /= sum_s2*sum_s2;
    
    x = (k-sum_mu)/sp;
    x2 = x*x;
    
    PWN = (-x2/2
    +numpy.log(1+gamma1/6*x*(x2-3)+gamma2/24*(x2*x2-6*x2+3)
    +gamma1*gamma1/72*(((x2-15)*x2+45)*x2-15))
    -numpy.log(2*math.pi)/2 -numpy.log(sp));
    
    log_cdf += PWN;
    return log_cdf;

def multinomCDF(G, k, p, tau_p):
    return numpy.exp(multinomCDF_log(G, k, p, tau_p ));

# %%
import copy

"""
To get a random multinomial icdf value from a solution space.
For the Ranking Algorithm, it cannot be used because the solutions are not continuous.
"""
def multinomial_icdf(G, k, p, a):
#     tau_p = [k] + list((numpy.round(numpy.array(p)*k))[1:]);
    tau_p = [k] + list(((numpy.array(p)*k).astype(int))[1:]);
    temp = copy.copy(tau_p)
    i = 1;
    cdf = multinomCDF(G, k, p, tau_p)
    found = 0
    while(found == 0):
        if(cdf > a):
            temp[i] = temp[i]-1;
            if(multinomCDF(G, k, p, temp) > a):
                tau_p = copy.copy(temp);
                cdf = multinomCDF(G, k, p, tau_p)
            else:
                found = 1;
  
        elif(cdf < a):
            temp[i] = temp[i]+1;
            if(multinomCDF(G, k, p, temp) < a):
                tau_p = copy.copy(temp);
                cdf = multinomCDF(G, k, p, tau_p)
            else:
                tau_p[i] = tau_p[i]+1;
                cdf = multinomCDF(G, k, p, tau_p)
                found = 1;    
        else:
            found = 1
        if(i == (len(tau_p)-1)):
            i = 1;
        else:
            i = i+1;
    return tau_p


"""
To find a continuous multinomial icdf solution from a solution space.
Used for the Ranking Algorithm.
If the multinomial_CDF with tau alreay results in the value > a, return tau.
Else calculate the multinomial_CDF of tau in each case when each element of tau is increased by 1.
Compare the value and take the tau that produces the closest multinomial_CDF to a, which is also > a.

For example, initial tau: [0, 0, 0, 0]
if: 
    multinomial_CDF(G, k, p, tau) > a, return tau
else:
    compare:
        multinomial_CDF(G, k, p, [1, 0, 0, 0])
        multinomial_CDF(G, k, p, [0, 1, 0, 0])
        multinomial_CDF(G, k, p, [0, 0, 1, 0])
        multinomial_CDF(G, k, p, [0, 0, 0, 1])
    and take the increased tau with its multinomial_CDF > a and closest to a    

"""
def multinomial_icdf_continuous(G, k, p, a, tau):
    tau_p = [k] + list(tau);
    temp = copy.copy(tau_p)
    cdf = multinomCDF(G, k, p, tau_p)
    new_cdf = 0;
    initial = 1;
    not_fulfilled = 0;
    
    if(cdf > a):
        return tau_p;
    for i in range(len(tau_p)-1):
        temp[i+1] = temp[i+1]+1;
        if(initial == 1):
            tau_p = copy.copy(temp);
            cdf = multinomCDF(G, k, p, tau_p);
            initial = 0;
        else:
            new_cdf = multinomCDF(G, k, p, temp)
            if(new_cdf >= a and new_cdf >= cdf):
                tau_p = copy.copy(temp);
                cdf = multinomCDF(G, k, p, tau_p); 
        if(new_cdf >= a or cdf >= a):
            if(not_fulfilled == 1):
                tau_p = copy.copy(temp);
                not_fulfilled = 0;
            else:
                temp[i+1] = temp[i+1]-1
                not_fulfilled = 0
        else:
            not_fulfilled = 1
    return tau_p

"""
Finds the target group which does not achieve the minimum target.
"""
def find_target(least_items, count, groups):
    for i in least_items:
        for j in range(len(i)):
            if(i[j] > count[j+1]):
                return groups[j+1];

# %%
import pandas as pd
"""
Example Case for Ranking Algorithm without considering the quality

Non-protected: White
Protected: Black, Asian, Hispanic, Half
"""

# races = ['White', 'Black', 'Asian', 'Hispanic', 'Half'];
# p = [0.4, 0.2, 0.2, 0.1, 0.1];

races = ['White', 'Black', 'Asian', 'Hispanic'];
p = [0.4, 0.3, 0.2, 0.2];
a = 0.1;
k = 100;
positions = numpy.array(list(range(k))) + 1;
# prob = (numpy.array(list(range(8)))+1)/10.0;
least_items = [];
"""
tau is used for the multinomial_icdf_continuous. 
Initialized as an array of zeros with its length identical with the number of protected groups.
For this example, therefore tau=[0.0, 0.0, 0.0, 0.0]
"""
tau = numpy.zeros(len(races)-1);

# for i in positions:
#     tau_p = multinomial_icdf(len(p), i, p , a)[1:]
#     least_items.append(numpy.array(tau_p));

for i in positions:
    tau_p = multinomial_icdf_continuous(len(p), i, p , a, tau)[1:]
    least_items.append(numpy.array(tau_p));
    tau = copy.copy(tau_p);

# for i in range (k):
#     print i+1,"  : ",least_items[i];
#     test = numpy.append([i+1],least_items[i])
#     print "CDF: ",multinomCDF(4, i+1, p, test)
#     test = []
# print"------------------------------------"    
# multinomial_icdf_continuous(len(p), 5, p , a, [0,0,1,2])[1:]
for i in range (k):
    print i+1,"  : ",least_items[i];
    test = numpy.append([i+1],least_items[i])
    print "CDF: ",multinomCDF(4, i+1, p, test)
    test = []
# Out:
# 1   :  [ 0.  0.  0.]
# CDF:  0.442534455177
# 2   :  [ 0.  0.  0.]
# CDF:  0.117196091393
# 3   :  [ 1.  0.  0.]
# CDF:  0.15957693129
# 4   :  [ 1.  0.  1.]
# CDF:  0.187658158277
# 5   :  [ 1.  1.  1.]
# CDF:  0.264194596884
# 6   :  [ 1.  1.  1.]
# CDF:  0.149895660161
# 7   :  [ 2.  1.  1.]
# CDF:  0.188783403818
# 8   :  [ 2.  1.  1.]
# CDF:  0.110509835579
# 9   :  [ 2.  1.  2.]
# CDF:  0.127003009222
# 10   :  [ 2.  2.  2.]
# CDF:  0.159818105454
# 11   :  [ 3.  2.  2.]
# CDF:  0.202668614698
# 12   :  [ 3.  2.  2.]
# CDF:  0.133920926304
# 13   :  [ 4.  2.  2.]
# CDF:  0.149607415843
# 14   :  [ 4.  2.  3.]
# CDF:  0.173398969352
# 15   :  [ 4.  2.  3.]
# CDF:  0.119040374541
# 16   :  [ 4.  3.  3.]
# CDF:  0.151186869153
# 17   :  [ 4.  3.  3.]
# CDF:  0.103642765481
# 18   :  [ 5.  3.  3.]
# CDF:  0.122945146028
# 19   :  [ 5.  4.  3.]
# CDF:  0.13928682269
# 20   :  [ 5.  4.  4.]
# CDF:  0.164843810002
# 21   :  [ 5.  4.  4.]
# CDF:  0.119247450331
# 22   :  [ 6.  4.  4.]
# CDF:  0.142426382631
# 23   :  [ 6.  4.  4.]
# CDF:  0.103059837479
# 24   :  [ 7.  4.  4.]
# CDF:  0.114998553923
# 25   :  [ 7.  4.  5.]
# CDF:  0.132705830264
# 26   :  [ 7.  5.  5.]
# CDF:  0.158374749913
# 27   :  [ 7.  5.  5.]
# CDF:  0.119107251284
# 28   :  [ 8.  5.  5.]
# CDF:  0.134434954341
# 29   :  [ 8.  5.  5.]
# CDF:  0.100900179932
# 30   :  [ 8.  5.  6.]
# CDF:  0.114133982978
# 31   :  [ 8.  6.  6.]
# CDF:  0.132793294473
# 32   :  [ 8.  6.  6.]
# CDF:  0.100826851895
# 33   :  [ 9.  6.  6.]
# CDF:  0.116813568197
# 34   :  [ 9.  6.  7.]
# CDF:  0.128275792857
# 35   :  [ 9.  7.  7.]
# CDF:  0.144336087197
# 36   :  [ 9.  7.  7.]
# CDF:  0.112512509399
# 37   :  [ 10.   7.   7.]
# CDF:  0.130789934532
# 38   :  [ 10.   7.   7.]
# CDF:  0.101797981712
# 39   :  [ 11.   7.   7.]
# CDF:  0.113469140266
# 40   :  [ 11.   8.   7.]
# CDF:  0.126006273873
# 41   :  [ 11.   8.   8.]
# CDF:  0.142889756532
# 42   :  [ 11.   8.   8.]
# CDF:  0.113655181991
# 43   :  [ 12.   8.   8.]
# CDF:  0.127424074914
# 44   :  [ 12.   8.   8.]
# CDF:  0.101123316653
# 45   :  [ 12.   8.   9.]
# CDF:  0.110993130205
# 46   :  [ 12.   9.   9.]
# CDF:  0.124125867476
# 47   :  [ 13.   9.   9.]
# CDF:  0.139794442316
# 48   :  [ 13.   9.   9.]
# CDF:  0.113004950897
# 49   :  [ 14.   9.   9.]
# CDF:  0.123332002761
# 50   :  [ 14.  10.   9.]
# CDF:  0.135160164677
# 51   :  [ 14.  10.   9.]
# CDF:  0.109974222992
# 52   :  [ 14.  10.  10.]
# CDF:  0.123679977989
# 53   :  [ 14.  10.  10.]
# CDF:  0.100234280648
# 54   :  [ 15.  10.  10.]
# CDF:  0.111203646981
# 55   :  [ 15.  11.  10.]
# CDF:  0.120757339586
# 56   :  [ 15.  11.  11.]
# CDF:  0.133133599587
# 57   :  [ 15.  11.  11.]
# CDF:  0.109491646967
# 58   :  [ 16.  11.  11.]
# CDF:  0.121949651639
# 59   :  [ 16.  11.  11.]
# CDF:  0.100088757575
# 60   :  [ 17.  11.  11.]
# CDF:  0.108656151007
# 61   :  [ 17.  12.  11.]
# CDF:  0.118763898298
# 62   :  [ 17.  12.  12.]
# CDF:  0.131611741176
# 63   :  [ 17.  12.  12.]
# CDF:  0.109436015836
# 64   :  [ 18.  12.  12.]
# CDF:  0.119359077275
# 65   :  [ 18.  12.  13.]
# CDF:  0.128532504813
# 66   :  [ 18.  12.  13.]
# CDF:  0.107365644262
# 67   :  [ 18.  13.  13.]
# CDF:  0.117909200526
# 68   :  [ 19.  13.  13.]
# CDF:  0.129114674973
# 69   :  [ 19.  13.  13.]
# CDF:  0.108376236523
# 70   :  [ 20.  13.  13.]
# CDF:  0.116196178999
# 71   :  [ 20.  13.  14.]
# CDF:  0.125837429347
# 72   :  [ 20.  13.  14.]
# CDF:  0.106044711035
# 73   :  [ 20.  14.  14.]
# CDF:  0.116951907413
# 74   :  [ 21.  14.  14.]
# CDF:  0.125947169755
# 75   :  [ 21.  14.  14.]
# CDF:  0.106586624502
# 76   :  [ 21.  14.  15.]
# CDF:  0.114661249589
# 77   :  [ 21.  15.  15.]
# CDF:  0.124708030093
# 78   :  [ 21.  15.  15.]
# CDF:  0.105794085297
# 79   :  [ 22.  15.  15.]
# CDF:  0.115192203753
# 80   :  [ 22.  15.  16.]
# CDF:  0.122508903482
# 81   :  [ 22.  15.  16.]
# CDF:  0.104288703444
# 82   :  [ 23.  15.  16.]
# CDF:  0.11269662788
# 83   :  [ 23.  16.  16.]
# CDF:  0.123056891956
# 84   :  [ 23.  16.  16.]
# CDF:  0.105145152349
# 85   :  [ 24.  16.  16.]
# CDF:  0.112842020096
# 86   :  [ 24.  16.  17.]
# CDF:  0.120608782115
# 87   :  [ 24.  16.  17.]
# CDF:  0.103369517157
# 88   :  [ 24.  17.  17.]
# CDF:  0.112130948256
# 89   :  [ 25.  17.  17.]
# CDF:  0.120751080234
# 90   :  [ 25.  17.  17.]
# CDF:  0.103833967827
# 91   :  [ 25.  17.  18.]
# CDF:  0.110404162848
# 92   :  [ 25.  18.  18.]
# CDF:  0.118461826868
# 93   :  [ 25.  18.  18.]
# CDF:  0.102032498507
# 94   :  [ 26.  18.  18.]
# CDF:  0.110879824466
# 95   :  [ 27.  18.  18.]
# CDF:  0.117960041228
# 96   :  [ 27.  18.  18.]
# CDF:  0.102012968496
# 97   :  [ 27.  18.  19.]
# CDF:  0.108930928611
# 98   :  [ 27.  19.  19.]
# CDF:  0.117320203922
# 99   :  [ 27.  19.  19.]
# CDF:  0.101630023486
# 100   :  [ 28.  19.  19.]
# CDF:  0.109073235759

# %%
multinomCDF(4, 3, p, [4,1,0,0])
# Out:
# 0.22554716834129629

# %%
rank = [];
count = [0,0,0,0,0];
random_choice = "";
chosen = 0;
num = 1;
swap = 0;
target = "";
for i in least_items:
    for j in range(len(i)):
        if(i[j] > count[j+1] and chosen == 0):
            rank.append(races[j+1]);
            print "chosen", races[j+1];
            count[j+1] += 1;
            chosen = 1;
            if(any(count[a+1]<i[a] for a in range(len(i)))):
                swap = len(rank)-1;
                print"-------------------------------------------"
                while(any(count[a+1]<i[a] for a in range(len(i)))):
                    target = find_target(least_items, count, races);
                    if(rank[swap] == races[0]):
                        rank[swap] = target;
                        print "swap",rank[swap];
                        print "count before", count
                        count[races.index(target)] += 1;
                        count[0] -= 1;
                        print "count after",count
                        print "swap index",swap
                    swap -= 1;    
                        
            print "Minimum achieved? ", all(count[a+1]>=i[a] for a in range(len(i)))
    if(chosen == 0):
        random_choice = numpy.random.choice(races, 1, p=p);
        print random_choice;
        rank.append(random_choice[0]);
        count[races.index(random_choice)] += 1;
    print num, ": ", count;
    num = num+1;
    chosen = 0;
# Out:
# ['Hispanic']
# 1 :  [0, 0, 0, 1, 0]
# ['White']
# 2 :  [1, 0, 0, 1, 0]
# ['Asian']
# 3 :  [1, 0, 1, 1, 0]
# ['Hispanic']
# 4 :  [1, 0, 1, 2, 0]
# chosen Asian
# Minimum achieved?  True
# 5 :  [1, 0, 2, 2, 0]
# chosen Black
# Minimum achieved?  True
# 6 :  [1, 1, 2, 2, 0]
# ['White']
# 7 :  [2, 1, 2, 2, 0]
# ['Asian']
# 8 :  [2, 1, 3, 2, 0]
# ['Black']
# 9 :  [2, 2, 3, 2, 0]
# ['Asian']
# 10 :  [2, 2, 4, 2, 0]
# ['White']
# 11 :  [3, 2, 4, 2, 0]
# ['Black']
# 12 :  [3, 3, 4, 2, 0]
# ['Black']
# 13 :  [3, 4, 4, 2, 0]
# chosen Asian
# Minimum achieved?  True
# 14 :  [3, 4, 5, 2, 0]
# ['Black']
# 15 :  [3, 5, 5, 2, 0]
# ['White']
# 16 :  [4, 5, 5, 2, 0]
# chosen Asian
# Minimum achieved?  True
# 17 :  [4, 5, 6, 2, 0]
# chosen Hispanic
# Minimum achieved?  True
# 18 :  [4, 5, 6, 3, 0]
# chosen Hispanic
# Minimum achieved?  True
# 19 :  [4, 5, 6, 4, 0]
# ['White']
# 20 :  [5, 5, 6, 4, 0]
# ['White']
# 21 :  [6, 5, 6, 4, 0]
# ['Hispanic']
# 22 :  [6, 5, 6, 5, 0]
# ['White']
# 23 :  [7, 5, 6, 5, 0]
# ['Hispanic']
# 24 :  [7, 5, 6, 6, 0]
# ['Hispanic']
# 25 :  [7, 5, 6, 7, 0]
# chosen Asian
# Minimum achieved?  True
# 26 :  [7, 5, 7, 7, 0]
# chosen Asian
# Minimum achieved?  True
# 27 :  [7, 5, 8, 7, 0]
# chosen Black
# Minimum achieved?  True
# 28 :  [7, 6, 8, 7, 0]
# ['White']
# 29 :  [8, 6, 8, 7, 0]
# ['Asian']
# 30 :  [8, 6, 9, 7, 0]
# chosen Black
# Minimum achieved?  True
# 31 :  [8, 7, 9, 7, 0]
# ['Asian']
# 32 :  [8, 7, 10, 7, 0]
# ['Asian']
# 33 :  [8, 7, 11, 7, 0]
# ['Black']
# 34 :  [8, 8, 11, 7, 0]
# ['Black']
# 35 :  [8, 9, 11, 7, 0]
# ['Hispanic']
# 36 :  [8, 9, 11, 8, 0]
# ['Black']
# 37 :  [8, 10, 11, 8, 0]
# ['Asian']
# 38 :  [8, 10, 12, 8, 0]
# ['Hispanic']
# 39 :  [8, 10, 12, 9, 0]
# ['White']
# 40 :  [9, 10, 12, 9, 0]
# ['White']
# 41 :  [10, 10, 12, 9, 0]
# ['Hispanic']
# 42 :  [10, 10, 12, 10, 0]
# ['White']
# 43 :  [11, 10, 12, 10, 0]
# ['White']
# 44 :  [12, 10, 12, 10, 0]
# ['Black']
# 45 :  [12, 11, 12, 10, 0]
# ['Asian']
# 46 :  [12, 11, 13, 10, 0]
# ['Black']
# 47 :  [12, 12, 13, 10, 0]
# ['Black']
# 48 :  [12, 13, 13, 10, 0]
# ['White']
# 49 :  [13, 13, 13, 10, 0]
# ['Asian']
# 50 :  [13, 13, 14, 10, 0]
# ['Hispanic']
# 51 :  [13, 13, 14, 11, 0]
# ['Asian']
# 52 :  [13, 13, 15, 11, 0]
# ['White']
# 53 :  [14, 13, 15, 11, 0]
# ['Black']
# 54 :  [14, 14, 15, 11, 0]
# ['Asian']
# 55 :  [14, 14, 16, 11, 0]
# ['White']
# 56 :  [15, 14, 16, 11, 0]
# ['Black']
# 57 :  [15, 15, 16, 11, 0]
# ['Hispanic']
# 58 :  [15, 15, 16, 12, 0]
# ['Asian']
# 59 :  [15, 15, 17, 12, 0]
# ['White']
# 60 :  [16, 15, 17, 12, 0]
# ['Black']
# 61 :  [16, 16, 17, 12, 0]
# ['White']
# 62 :  [17, 16, 17, 12, 0]
# ['White']
# 63 :  [18, 16, 17, 12, 0]
# ['Asian']
# 64 :  [18, 16, 18, 12, 0]
# ['White']
# 65 :  [19, 16, 18, 12, 0]
# ['Black']
# 66 :  [19, 17, 18, 12, 0]
# ['White']
# 67 :  [20, 17, 18, 12, 0]
# ['Black']
# 68 :  [20, 18, 18, 12, 0]
# ['Asian']
# 69 :  [20, 18, 19, 12, 0]
# ['White']
# 70 :  [21, 18, 19, 12, 0]
# ['White']
# 71 :  [22, 18, 19, 12, 0]
# ['White']
# 72 :  [23, 18, 19, 12, 0]
# ['Asian']
# 73 :  [23, 18, 20, 12, 0]
# ['Black']
# 74 :  [23, 19, 20, 12, 0]
# ['White']
# 75 :  [24, 19, 20, 12, 0]
# ['Asian']
# 76 :  [24, 19, 21, 12, 0]
# ['White']
# 77 :  [25, 19, 21, 12, 0]
# chosen Hispanic
# Minimum achieved?  True
# 78 :  [25, 19, 21, 13, 0]
# ['White']
# 79 :  [26, 19, 21, 13, 0]
# chosen Black
# Minimum achieved?  True
# 80 :  [26, 20, 21, 13, 0]
# ['White']
# 81 :  [27, 20, 21, 13, 0]
# chosen Hispanic
# Minimum achieved?  True
# 82 :  [27, 20, 21, 14, 0]
# chosen Black
# Minimum achieved?  True
# 83 :  [27, 21, 21, 14, 0]
# ['Asian']
# 84 :  [27, 21, 22, 14, 0]
# ['Asian']
# 85 :  [27, 21, 23, 14, 0]
# ['Black']
# 86 :  [27, 22, 23, 14, 0]
# ['Asian']
# 87 :  [27, 22, 24, 14, 0]
# ['Asian']
# 88 :  [27, 22, 25, 14, 0]
# ['Asian']
# 89 :  [27, 22, 26, 14, 0]
# ['Black']
# 90 :  [27, 23, 26, 14, 0]
# ['White']
# 91 :  [28, 23, 26, 14, 0]
# ['White']
# 92 :  [29, 23, 26, 14, 0]
# ['Asian']
# 93 :  [29, 23, 27, 14, 0]
# chosen Hispanic
# Minimum achieved?  True
# 94 :  [29, 23, 27, 15, 0]
# chosen Black
# Minimum achieved?  True
# 95 :  [29, 24, 27, 15, 0]
# ['White']
# 96 :  [30, 24, 27, 15, 0]
# ['Black']
# 97 :  [30, 25, 27, 15, 0]
# ['White']
# 98 :  [31, 25, 27, 15, 0]
# ['White']
# 99 :  [32, 25, 27, 15, 0]
# chosen Hispanic
# Minimum achieved?  True
# 100 :  [32, 25, 27, 16, 0]

# %%
for i in range(len(rank)):
    print "k =",i+1,": ",rank[i]
# Out:
# k = 1 :  Hispanic
# k = 2 :  White
# k = 3 :  Asian
# k = 4 :  Hispanic
# k = 5 :  Asian
# k = 6 :  Black
# k = 7 :  White
# k = 8 :  Asian
# k = 9 :  Black
# k = 10 :  Asian
# k = 11 :  White
# k = 12 :  Black
# k = 13 :  Black
# k = 14 :  Asian
# k = 15 :  Black
# k = 16 :  White
# k = 17 :  Asian
# k = 18 :  Hispanic
# k = 19 :  Hispanic
# k = 20 :  White
# k = 21 :  White
# k = 22 :  Hispanic
# k = 23 :  White
# k = 24 :  Hispanic
# k = 25 :  Hispanic
# k = 26 :  Asian
# k = 27 :  Asian
# k = 28 :  Black
# k = 29 :  White
# k = 30 :  Asian
# k = 31 :  Black
# k = 32 :  Asian
# k = 33 :  Asian
# k = 34 :  Black
# k = 35 :  Black
# k = 36 :  Hispanic
# k = 37 :  Black
# k = 38 :  Asian
# k = 39 :  Hispanic
# k = 40 :  White
# k = 41 :  White
# k = 42 :  Hispanic
# k = 43 :  White
# k = 44 :  White
# k = 45 :  Black
# k = 46 :  Asian
# k = 47 :  Black
# k = 48 :  Black
# k = 49 :  White
# k = 50 :  Asian
# k = 51 :  Hispanic
# k = 52 :  Asian
# k = 53 :  White
# k = 54 :  Black
# k = 55 :  Asian
# k = 56 :  White
# k = 57 :  Black
# k = 58 :  Hispanic
# k = 59 :  Asian
# k = 60 :  White
# k = 61 :  Black
# k = 62 :  White
# k = 63 :  White
# k = 64 :  Asian
# k = 65 :  White
# k = 66 :  Black
# k = 67 :  White
# k = 68 :  Black
# k = 69 :  Asian
# k = 70 :  White
# k = 71 :  White
# k = 72 :  White
# k = 73 :  Asian
# k = 74 :  Black
# k = 75 :  White
# k = 76 :  Asian
# k = 77 :  White
# k = 78 :  Hispanic
# k = 79 :  White
# k = 80 :  Black
# k = 81 :  White
# k = 82 :  Hispanic
# k = 83 :  Black
# k = 84 :  Asian
# k = 85 :  Asian
# k = 86 :  Black
# k = 87 :  Asian
# k = 88 :  Asian
# k = 89 :  Asian
# k = 90 :  Black
# k = 91 :  White
# k = 92 :  White
# k = 93 :  Asian
# k = 94 :  Hispanic
# k = 95 :  Black
# k = 96 :  White
# k = 97 :  Black
# k = 98 :  White
# k = 99 :  White
# k = 100 :  Hispanic

# %%
"""
Read Data set (.json), saves as array of dictionaries of items
"""
import pandas as pd
import json
import ast

json_data = open('./test_data_sets_for_ipynb/test_data_set_500.json').read()
data = numpy.array(json_data.split("\n"))
data_set = []
for i in data:
    data_set.append(ast.literal_eval(i))
attribute = {"Gender": 4}   
data_set
# Out:
# [{'Gender': 0, 'Uni score': 0.5344585435},
#  {'Gender': 2, 'Uni score': 1.0160173543},
#  {'Gender': 0, 'Uni score': 0.4573686375},
#  {'Gender': 1, 'Uni score': 0.6513702354},
#  {'Gender': 1, 'Uni score': 0.5683681534},
#  {'Gender': 3, 'Uni score': 0.7767882583},
#  {'Gender': 1, 'Uni score': 0.5720163193},
#  {'Gender': 0, 'Uni score': 0.3646469529},
#  {'Gender': 0, 'Uni score': 0.4648817221},
#  {'Gender': 0, 'Uni score': 0.5350985713},
#  {'Gender': 2, 'Uni score': 1.1770626574},
#  {'Gender': 3, 'Uni score': -0.670887751},
#  {'Gender': 0, 'Uni score': 0.216323686},
#  {'Gender': 2, 'Uni score': 1.5137061267},
#  {'Gender': 0, 'Uni score': 0.4795152902},
#  {'Gender': 1, 'Uni score': 0.8011014761},
#  {'Gender': 2, 'Uni score': 1.1606679187},
#  {'Gender': 3, 'Uni score': 1.0495726362},
#  {'Gender': 3, 'Uni score': 0.309442046},
#  {'Gender': 2, 'Uni score': 1.1198528938},
#  {'Gender': 3, 'Uni score': 1.5733224326},
#  {'Gender': 1, 'Uni score': 0.3624285705},
#  {'Gender': 2, 'Uni score': 1.3079964314},
#  {'Gender': 3, 'Uni score': -0.1042081031},
#  {'Gender': 3, 'Uni score': -0.1490012572},
#  {'Gender': 0, 'Uni score': 0.1486543697},
#  {'Gender': 3, 'Uni score': -0.652960729},
#  {'Gender': 3, 'Uni score': 0.969931477},
#  {'Gender': 2, 'Uni score': 0.7750072341},
#  {'Gender': 3, 'Uni score': 1.7120243436},
#  {'Gender': 2, 'Uni score': 2.1583313833},
#  {'Gender': 3, 'Uni score': 0.0217424869},
#  {'Gender': 1, 'Uni score': 0.1668027567},
#  {'Gender': 2, 'Uni score': 1.607066781},
#  {'Gender': 1, 'Uni score': 0.6911401779},
#  {'Gender': 1, 'Uni score': 0.1554786558},
#  {'Gender': 1, 'Uni score': 0.339103972},
#  {'Gender': 0, 'Uni score': 0.4315642117},
#  {'Gender': 1, 'Uni score': 0.2611366619},
#  {'Gender': 2, 'Uni score': -0.0621011088},
#  {'Gender': 3, 'Uni score': -1.5320029671},
#  {'Gender': 3, 'Uni score': 0.5437386011},
#  {'Gender': 3, 'Uni score': 0.6553756805},
#  {'Gender': 1, 'Uni score': 0.2784483237},
#  {'Gender': 0, 'Uni score': 0.5390479252},
#  {'Gender': 2, 'Uni score': 2.2329253232},
#  {'Gender': 3, 'Uni score': 0.5457188468},
#  {'Gender': 3, 'Uni score': -0.5190927401},
#  {'Gender': 0, 'Uni score': 0.3521748357},
#  {'Gender': 3, 'Uni score': 1.1185564133},
#  {'Gender': 3, 'Uni score': -0.916342485},
#  {'Gender': 0, 'Uni score': 0.1530418347},
#  {'Gender': 1, 'Uni score': 0.5979920427},
#  {'Gender': 0, 'Uni score': 0.4190865699},
#  {'Gender': 1, 'Uni score': 0.5961380006},
#  {'Gender': 0, 'Uni score': 0.3818762104},
#  {'Gender': 1, 'Uni score': 0.6749715095},
#  {'Gender': 2, 'Uni score': 1.2909166626},
#  {'Gender': 1, 'Uni score': 0.4674172672},
#  {'Gender': 2, 'Uni score': 0.7862900384},
#  {'Gender': 0, 'Uni score': 0.2384146906},
#  {'Gender': 1, 'Uni score': 0.3697208596},
#  {'Gender': 0, 'Uni score': 0.2045243356},
#  {'Gender': 2, 'Uni score': 1.3643975716},
#  {'Gender': 1, 'Uni score': 0.7883963507},
#  {'Gender': 1, 'Uni score': 0.0396209597},
#  {'Gender': 3, 'Uni score': -0.876111095},
#  {'Gender': 2, 'Uni score': 0.8918062018},
#  {'Gender': 2, 'Uni score': 0.6577561847},
#  {'Gender': 0, 'Uni score': 0.6397513191},
#  {'Gender': 2, 'Uni score': 0.8677577493},
#  {'Gender': 0, 'Uni score': 0.4132198218},
#  {'Gender': 0, 'Uni score': 0.5016558954},
#  {'Gender': 1, 'Uni score': 0.2882420634},
#  {'Gender': 1, 'Uni score': 0.4049221921},
#  {'Gender': 0, 'Uni score': 0.5793490205},
#  {'Gender': 0, 'Uni score': 0.5239321721},
#  {'Gender': 0, 'Uni score': 0.4094070685},
#  {'Gender': 3, 'Uni score': -0.6849384692},
#  {'Gender': 1, 'Uni score': 0.4563889096},
#  {'Gender': 2, 'Uni score': 0.3215734851},
#  {'Gender': 3, 'Uni score': -0.4419414281},
#  {'Gender': 0, 'Uni score': 0.4075023943},
#  {'Gender': 3, 'Uni score': 0.1849632024},
#  {'Gender': 0, 'Uni score': 0.3085415758},
#  {'Gender': 3, 'Uni score': 0.7066375642},
#  {'Gender': 2, 'Uni score': 1.3983462286},
#  {'Gender': 3, 'Uni score': 1.0084577042},
#  {'Gender': 3, 'Uni score': 0.4611202323},
#  {'Gender': 2, 'Uni score': 1.1170529944},
#  {'Gender': 3, 'Uni score': 0.7266932169},
#  {'Gender': 2, 'Uni score': 1.3276840567},
#  {'Gender': 0, 'Uni score': 0.0616613591},
#  {'Gender': 3, 'Uni score': 0.8349708936},
#  {'Gender': 0, 'Uni score': 0.2098631326},
#  {'Gender': 2, 'Uni score': 0.6958927058},
#  {'Gender': 2, 'Uni score': 0.7008931024},
#  {'Gender': 0, 'Uni score': 0.5285858826},
#  {'Gender': 2, 'Uni score': 1.0008894965},
#  {'Gender': 3, 'Uni score': 0.0912696452},
#  {'Gender': 1, 'Uni score': 0.2565909371},
#  {'Gender': 2, 'Uni score': 1.2494340619},
#  {'Gender': 2, 'Uni score': 1.0422591223},
#  {'Gender': 2, 'Uni score': 1.1910696683},
#  {'Gender': 0, 'Uni score': 0.1253270894},
#  {'Gender': 0, 'Uni score': 0.45930737},
#  {'Gender': 3, 'Uni score': -0.1213811659},
#  {'Gender': 1, 'Uni score': 0.3312217556},
#  {'Gender': 0, 'Uni score': 0.2094579645},
#  {'Gender': 3, 'Uni score': 0.9245611388},
#  {'Gender': 3, 'Uni score': 1.3295651447},
#  {'Gender': 0, 'Uni score': 0.0709307989},
#  {'Gender': 3, 'Uni score': -1.1539463599},
#  {'Gender': 0, 'Uni score': 0.2267995087},
#  {'Gender': 2, 'Uni score': 1.8152601943},
#  {'Gender': 3, 'Uni score': 0.9970998879},
#  {'Gender': 2, 'Uni score': 0.5201850447},
#  {'Gender': 0, 'Uni score': 0.5112674307},
#  {'Gender': 3, 'Uni score': 1.1910788359},
#  {'Gender': 3, 'Uni score': 0.5286603036},
#  {'Gender': 0, 'Uni score': 0.197860776},
#  {'Gender': 3, 'Uni score': 1.6552765032},
#  {'Gender': 1, 'Uni score': 0.5592814987},
#  {'Gender': 2, 'Uni score': -0.1741150416},
#  {'Gender': 0, 'Uni score': 0.6131792943},
#  {'Gender': 3, 'Uni score': -0.2972016337},
#  {'Gender': 2, 'Uni score': 0.7159731847},
#  {'Gender': 3, 'Uni score': 0.2718679652},
#  {'Gender': 1, 'Uni score': 0.2276311143},
#  {'Gender': 0, 'Uni score': 0.5220121889},
#  {'Gender': 0, 'Uni score': 0.4728283861},
#  {'Gender': 0, 'Uni score': 0.1421234516},
#  {'Gender': 1, 'Uni score': 0.4072923722},
#  {'Gender': 1, 'Uni score': 0.4140897436},
#  {'Gender': 3, 'Uni score': 0.7328648582},
#  {'Gender': 1, 'Uni score': 0.1170586936},
#  {'Gender': 1, 'Uni score': -0.0126092095},
#  {'Gender': 1, 'Uni score': 0.9063713513},
#  {'Gender': 0, 'Uni score': 0.4460960777},
#  {'Gender': 2, 'Uni score': 1.3349554977},
#  {'Gender': 1, 'Uni score': 0.8416676898},
#  {'Gender': 0, 'Uni score': 0.4026426029},
#  {'Gender': 1, 'Uni score': 0.6509077532},
#  {'Gender': 1, 'Uni score': 0.5308264946},
#  {'Gender': 1, 'Uni score': -0.1087180593},
#  {'Gender': 0, 'Uni score': 0.3769125933},
#  {'Gender': 1, 'Uni score': 0.4247640175},
#  {'Gender': 1, 'Uni score': 0.4985791617},
#  {'Gender': 2, 'Uni score': 0.7053114732},
#  {'Gender': 1, 'Uni score': 0.1143608552},
#  {'Gender': 1, 'Uni score': -0.1838593509},
#  {'Gender': 1, 'Uni score': 0.4818451132},
#  {'Gender': 2, 'Uni score': 1.095239528},
#  {'Gender': 3, 'Uni score': -0.2680715572},
#  {'Gender': 0, 'Uni score': 0.1379826481},
#  {'Gender': 2, 'Uni score': 0.6757827215},
#  {'Gender': 0, 'Uni score': 0.5755475355},
#  {'Gender': 1, 'Uni score': 0.2834848835},
#  {'Gender': 1, 'Uni score': 0.1377665954},
#  {'Gender': 0, 'Uni score': 0.1504323874},
#  {'Gender': 1, 'Uni score': 0.0499202951},
#  {'Gender': 1, 'Uni score': 0.4961511799},
#  {'Gender': 1, 'Uni score': 0.2437277239},
#  {'Gender': 0, 'Uni score': 0.4534905672},
#  {'Gender': 1, 'Uni score': 0.3990067092},
#  {'Gender': 1, 'Uni score': -0.2476213429},
#  {'Gender': 3, 'Uni score': -1.8138360858},
#  {'Gender': 3, 'Uni score': -0.2119372243},
#  {'Gender': 0, 'Uni score': 0.4583319937},
#  {'Gender': 0, 'Uni score': 0.3186888842},
#  {'Gender': 3, 'Uni score': 0.0272402968},
#  {'Gender': 2, 'Uni score': 0.5973570544},
#  {'Gender': 2, 'Uni score': 0.9157652549},
#  {'Gender': 0, 'Uni score': 0.2765552729},
#  {'Gender': 2, 'Uni score': 1.0858815805},
#  {'Gender': 2, 'Uni score': -0.4494073162},
#  {'Gender': 1, 'Uni score': 0.4479176764},
#  {'Gender': 0, 'Uni score': 0.2293521336},
#  {'Gender': 0, 'Uni score': 0.4267730833},
#  {'Gender': 0, 'Uni score': 0.5056467069},
#  {'Gender': 1, 'Uni score': 0.3646986314},
#  {'Gender': 1, 'Uni score': 0.1245786571},
#  {'Gender': 0, 'Uni score': 0.2825056427},
#  {'Gender': 2, 'Uni score': 1.5420521032},
#  {'Gender': 1, 'Uni score': 0.4428067755},
#  {'Gender': 2, 'Uni score': 1.257394427},
#  {'Gender': 1, 'Uni score': 0.1708241677},
#  {'Gender': 3, 'Uni score': 2.0609964935},
#  {'Gender': 3, 'Uni score': 1.4892304889},
#  {'Gender': 3, 'Uni score': -0.5544894894},
#  {'Gender': 0, 'Uni score': 0.3152308859},
#  {'Gender': 1, 'Uni score': 0.4769475068},
#  {'Gender': 0, 'Uni score': 0.249670093},
#  {'Gender': 1, 'Uni score': 0.2078289467},
#  {'Gender': 3, 'Uni score': 0.2970441883},
#  {'Gender': 3, 'Uni score': -0.7637691963},
#  {'Gender': 1, 'Uni score': 0.5151417788},
#  {'Gender': 0, 'Uni score': 0.3120278515},
#  {'Gender': 3, 'Uni score': 1.2357368777},
#  {'Gender': 3, 'Uni score': 0.1310367237},
#  {'Gender': 2, 'Uni score': 1.6596611711},
#  {'Gender': 0, 'Uni score': 0.2243804915},
#  {'Gender': 3, 'Uni score': 1.6993016628},
#  {'Gender': 3, 'Uni score': -0.5307976394},
#  {'Gender': 2, 'Uni score': 0.5129327626},
#  {'Gender': 3, 'Uni score': 0.9569161277},
#  {'Gender': 0, 'Uni score': 0.4953577222},
#  {'Gender': 1, 'Uni score': 0.1545025214},
#  {'Gender': 3, 'Uni score': -0.7353475745},
#  {'Gender': 3, 'Uni score': 0.8543509969},
#  {'Gender': 3, 'Uni score': -0.6209057146},
#  {'Gender': 1, 'Uni score': -0.0381643438},
#  {'Gender': 3, 'Uni score': 0.3973994639},
#  {'Gender': 0, 'Uni score': 0.5247654505},
#  {'Gender': 1, 'Uni score': 0.0467966284},
#  {'Gender': 1, 'Uni score': 0.1545469902},
#  {'Gender': 0, 'Uni score': 0.3957133095},
#  {'Gender': 1, 'Uni score': 0.0378176826},
#  {'Gender': 2, 'Uni score': 1.3569257041},
#  {'Gender': 0, 'Uni score': 0.3371427871},
#  {'Gender': 3, 'Uni score': -0.2125582159},
#  {'Gender': 0, 'Uni score': 0.2918139986},
#  {'Gender': 1, 'Uni score': 0.1318339093},
#  {'Gender': 2, 'Uni score': 1.528346343},
#  {'Gender': 1, 'Uni score': 0.1952875507},
#  {'Gender': 2, 'Uni score': 1.5608242271},
#  {'Gender': 3, 'Uni score': 0.5067100395},
#  {'Gender': 3, 'Uni score': 1.5378213219},
#  {'Gender': 2, 'Uni score': 1.2774082953},
#  {'Gender': 1, 'Uni score': 0.2738119995},
#  {'Gender': 2, 'Uni score': 2.0807305529},
#  {'Gender': 2, 'Uni score': 1.0116011105},
#  {'Gender': 1, 'Uni score': -0.0209656839},
#  {'Gender': 0, 'Uni score': 0.0193538015},
#  {'Gender': 0, 'Uni score': 0.1257812722},
#  {'Gender': 3, 'Uni score': 3.6487059175},
#  {'Gender': 0, 'Uni score': 0.0224518445},
#  {'Gender': 3, 'Uni score': -0.5068900795},
#  {'Gender': 2, 'Uni score': -0.595339326},
#  {'Gender': 3, 'Uni score': -0.0079363726},
#  {'Gender': 3, 'Uni score': 0.6573869016},
#  {'Gender': 2, 'Uni score': 0.7252999414},
#  {'Gender': 0, 'Uni score': 0.427222898},
#  {'Gender': 3, 'Uni score': 0.5826164064},
#  {'Gender': 2, 'Uni score': 1.3303467686},
#  {'Gender': 3, 'Uni score': 0.4555799279},
#  {'Gender': 2, 'Uni score': 0.7494825735},
#  {'Gender': 0, 'Uni score': 0.1975295264},
#  {'Gender': 1, 'Uni score': 0.6207679953},
#  {'Gender': 2, 'Uni score': 1.4140117415},
#  {'Gender': 0, 'Uni score': 0.4709883143},
#  {'Gender': 3, 'Uni score': -0.9412091148},
#  {'Gender': 1, 'Uni score': 0.7844390139},
#  {'Gender': 3, 'Uni score': 0.9115009704},
#  {'Gender': 2, 'Uni score': 0.924641422},
#  {'Gender': 2, 'Uni score': 0.6201790083},
#  {'Gender': 1, 'Uni score': 0.4803230953},
#  {'Gender': 0, 'Uni score': 0.5157314038},
#  {'Gender': 0, 'Uni score': 0.2210817631},
#  {'Gender': 0, 'Uni score': 0.3413471137},
#  {'Gender': 2, 'Uni score': 1.0192584456},
#  {'Gender': 2, 'Uni score': 0.1797276149},
#  {'Gender': 1, 'Uni score': 0.5402321149},
#  {'Gender': 3, 'Uni score': -0.0081600959},
#  {'Gender': 2, 'Uni score': 1.2984390242},
#  {'Gender': 1, 'Uni score': 0.2969915213},
#  {'Gender': 0, 'Uni score': 0.4550337442},
#  {'Gender': 0, 'Uni score': 0.382922236},
#  {'Gender': 3, 'Uni score': 0.254668022},
#  {'Gender': 3, 'Uni score': 1.3415649667},
#  {'Gender': 0, 'Uni score': 0.2121917452},
#  {'Gender': 0, 'Uni score': 0.5031821557},
#  {'Gender': 0, 'Uni score': 0.2730406071},
#  {'Gender': 0, 'Uni score': 0.4935376118},
#  {'Gender': 3, 'Uni score': 0.8248366556},
#  {'Gender': 0, 'Uni score': 0.1908752532},
#  {'Gender': 1, 'Uni score': 0.4777802052},
#  {'Gender': 1, 'Uni score': 0.3612949948},
#  {'Gender': 3, 'Uni score': 0.6153194035},
#  {'Gender': 2, 'Uni score': 1.7745054487},
#  {'Gender': 1, 'Uni score': 0.9564352348},
#  {'Gender': 0, 'Uni score': 0.2426934792},
#  {'Gender': 2, 'Uni score': 1.1972455578},
#  {'Gender': 2, 'Uni score': 0.6912146681},
#  {'Gender': 0, 'Uni score': 0.3616288102},
#  {'Gender': 0, 'Uni score': 0.2895772145},
#  {'Gender': 0, 'Uni score': 0.0882153322},
#  {'Gender': 3, 'Uni score': -1.0493633515},
#  {'Gender': 2, 'Uni score': 0.7895836691},
#  {'Gender': 2, 'Uni score': 1.7308071018},
#  {'Gender': 2, 'Uni score': 0.8673326816},
#  {'Gender': 1, 'Uni score': 0.825292331},
#  {'Gender': 3, 'Uni score': -0.7085812624},
#  {'Gender': 0, 'Uni score': 0.5185144924},
#  {'Gender': 0, 'Uni score': 0.1911862564},
#  {'Gender': 1, 'Uni score': 0.3132028348},
#  {'Gender': 2, 'Uni score': 0.8126149777},
#  {'Gender': 1, 'Uni score': 0.6673956425},
#  {'Gender': 1, 'Uni score': 0.3066925229},
#  {'Gender': 3, 'Uni score': 2.3147588598},
#  {'Gender': 2, 'Uni score': 1.0193238496},
#  {'Gender': 0, 'Uni score': 0.0690414578},
#  {'Gender': 1, 'Uni score': 0.2486788613},
#  {'Gender': 1, 'Uni score': 0.3290762251},
#  {'Gender': 1, 'Uni score': 0.3613900062},
#  {'Gender': 1, 'Uni score': 0.2710336487},
#  {'Gender': 2, 'Uni score': 1.5692812754},
#  {'Gender': 0, 'Uni score': 0.2028979125},
#  {'Gender': 3, 'Uni score': 1.2045219557},
#  {'Gender': 1, 'Uni score': 0.4523017536},
#  {'Gender': 1, 'Uni score': 0.7327512959},
#  {'Gender': 1, 'Uni score': 0.6805179616},
#  {'Gender': 3, 'Uni score': 0.936783401},
#  {'Gender': 0, 'Uni score': 0.5020234479},
#  {'Gender': 3, 'Uni score': 0.1574195982},
#  {'Gender': 1, 'Uni score': 0.303091036},
#  {'Gender': 0, 'Uni score': 0.570131607},
#  {'Gender': 1, 'Uni score': 0.6155720988},
#  {'Gender': 3, 'Uni score': -0.851897775},
#  {'Gender': 3, 'Uni score': 0.7930824409},
#  {'Gender': 2, 'Uni score': 0.655946262},
#  {'Gender': 0, 'Uni score': 0.5998471958},
#  {'Gender': 1, 'Uni score': 0.0406966677},
#  {'Gender': 1, 'Uni score': 0.3815852237},
#  {'Gender': 0, 'Uni score': 0.5879620438},
#  {'Gender': 2, 'Uni score': 1.3014913099},
#  {'Gender': 0, 'Uni score': 0.232756088},
#  {'Gender': 1, 'Uni score': -0.0606001206},
#  {'Gender': 0, 'Uni score': 0.4524279977},
#  {'Gender': 1, 'Uni score': 0.443332782},
#  {'Gender': 3, 'Uni score': 0.4313311545},
#  {'Gender': 2, 'Uni score': 0.6275881732},
#  {'Gender': 1, 'Uni score': 0.8102649339},
#  {'Gender': 0, 'Uni score': 0.1337244038},
#  {'Gender': 3, 'Uni score': -0.5297789444},
#  {'Gender': 0, 'Uni score': 0.6249890982},
#  {'Gender': 1, 'Uni score': 0.5428427889},
#  {'Gender': 0, 'Uni score': 0.3726290785},
#  {'Gender': 0, 'Uni score': 0.4223065156},
#  {'Gender': 0, 'Uni score': 0.4149870768},
#  {'Gender': 3, 'Uni score': 0.8508056115},
#  {'Gender': 2, 'Uni score': 1.066914717},
#  {'Gender': 1, 'Uni score': 0.6877514105},
#  {'Gender': 2, 'Uni score': 0.5786515917},
#  {'Gender': 3, 'Uni score': 0.0309999542},
#  {'Gender': 2, 'Uni score': 1.9456225999},
#  {'Gender': 0, 'Uni score': 0.4239385606},
#  {'Gender': 0, 'Uni score': 0.3696573297},
#  {'Gender': 2, 'Uni score': 1.0677049429},
#  {'Gender': 1, 'Uni score': 0.6549209192},
#  {'Gender': 2, 'Uni score': -0.4582219695},
#  {'Gender': 3, 'Uni score': -0.1542384461},
#  {'Gender': 2, 'Uni score': 1.3074553219},
#  {'Gender': 2, 'Uni score': 0.5593432438},
#  {'Gender': 1, 'Uni score': 0.4814463115},
#  {'Gender': 0, 'Uni score': 0.1970582092},
#  {'Gender': 1, 'Uni score': 0.4439123293},
#  {'Gender': 0, 'Uni score': 0.7887698602},
#  {'Gender': 3, 'Uni score': 0.1565941256},
#  {'Gender': 0, 'Uni score': 0.3909862135},
#  {'Gender': 2, 'Uni score': 1.3513477258},
#  {'Gender': 1, 'Uni score': -0.0056370641},
#  {'Gender': 3, 'Uni score': 0.1576077012},
#  {'Gender': 1, 'Uni score': 0.239299796},
#  {'Gender': 1, 'Uni score': 0.4655648931},
#  {'Gender': 0, 'Uni score': 0.384231161},
#  {'Gender': 2, 'Uni score': 0.4129617026},
#  {'Gender': 2, 'Uni score': 1.0147951625},
#  {'Gender': 0, 'Uni score': 0.4994284692},
#  {'Gender': 3, 'Uni score': -0.3207472658},
#  {'Gender': 1, 'Uni score': 0.2551465145},
#  {'Gender': 1, 'Uni score': 0.5379611624},
#  {'Gender': 1, 'Uni score': 0.6774923993},
#  {'Gender': 0, 'Uni score': 0.3335652376},
#  {'Gender': 3, 'Uni score': -0.092349986},
#  {'Gender': 3, 'Uni score': 2.3762623133},
#  {'Gender': 1, 'Uni score': 0.2211317324},
#  {'Gender': 1, 'Uni score': 0.8038716912},
#  {'Gender': 3, 'Uni score': 0.4269428789},
#  {'Gender': 0, 'Uni score': 0.0769258787},
#  {'Gender': 2, 'Uni score': 0.1195413348},
#  {'Gender': 3, 'Uni score': -0.5131303688},
#  {'Gender': 3, 'Uni score': 0.2806325337},
#  {'Gender': 0, 'Uni score': 0.4473015732},
#  {'Gender': 2, 'Uni score': 0.946238215},
#  {'Gender': 0, 'Uni score': 0.2676465587},
#  {'Gender': 0, 'Uni score': 0.4594466414},
#  {'Gender': 2, 'Uni score': 0.5404809361},
#  {'Gender': 3, 'Uni score': 0.539113481},
#  {'Gender': 0, 'Uni score': 0.6957812452},
#  {'Gender': 2, 'Uni score': 0.7552083023},
#  {'Gender': 3, 'Uni score': -0.5835723163},
#  {'Gender': 3, 'Uni score': 0.0524537684},
#  {'Gender': 1, 'Uni score': 0.5099644077},
#  {'Gender': 0, 'Uni score': 0.4712245838},
#  {'Gender': 2, 'Uni score': 0.8965341829},
#  {'Gender': 3, 'Uni score': 0.0271127963},
#  {'Gender': 1, 'Uni score': 0.7644476987},
#  {'Gender': 1, 'Uni score': 0.5638851735},
#  {'Gender': 2, 'Uni score': 1.1421321866},
#  {'Gender': 2, 'Uni score': 1.1750796865},
#  {'Gender': 2, 'Uni score': 1.1769075731},
#  {'Gender': 1, 'Uni score': 0.1634613642},
#  {'Gender': 0, 'Uni score': 0.4517019707},
#  {'Gender': 2, 'Uni score': 0.7924837718},
#  {'Gender': 1, 'Uni score': -0.002357945},
#  {'Gender': 3, 'Uni score': 2.371649435},
#  {'Gender': 1, 'Uni score': 0.5090119309},
#  {'Gender': 1, 'Uni score': 0.3465709096},
#  {'Gender': 2, 'Uni score': 0.8653317733},
#  {'Gender': 1, 'Uni score': 0.3423899646},
#  {'Gender': 0, 'Uni score': 0.2403584401},
#  {'Gender': 3, 'Uni score': 0.6057128433},
#  {'Gender': 0, 'Uni score': 0.3450757516},
#  {'Gender': 1, 'Uni score': 0.2581880531},
#  {'Gender': 1, 'Uni score': 0.6738594222},
#  {'Gender': 3, 'Uni score': -0.0203005053},
#  {'Gender': 3, 'Uni score': -2.1361683458},
#  {'Gender': 3, 'Uni score': 1.8843695208},
#  {'Gender': 0, 'Uni score': 0.3829142112},
#  {'Gender': 2, 'Uni score': 0.9257626571},
#  {'Gender': 0, 'Uni score': 0.5258621203},
#  {'Gender': 2, 'Uni score': 0.4534292821},
#  {'Gender': 2, 'Uni score': 0.7230153794},
#  {'Gender': 3, 'Uni score': 1.3262787345},
#  {'Gender': 1, 'Uni score': 0.2251428135},
#  {'Gender': 0, 'Uni score': 0.4652606875},
#  {'Gender': 2, 'Uni score': 0.6472485017},
#  {'Gender': 2, 'Uni score': 0.9027829891},
#  {'Gender': 1, 'Uni score': 0.446110048},
#  {'Gender': 2, 'Uni score': 1.1663039138},
#  {'Gender': 1, 'Uni score': 0.8070704632},
#  {'Gender': 3, 'Uni score': 0.6319825311},
#  {'Gender': 2, 'Uni score': 0.3031147538},
#  {'Gender': 2, 'Uni score': 1.1450200731},
#  {'Gender': 3, 'Uni score': 0.8466953456},
#  {'Gender': 0, 'Uni score': 0.1761813697},
#  {'Gender': 3, 'Uni score': 1.8331408126},
#  {'Gender': 3, 'Uni score': -1.3977808262},
#  {'Gender': 0, 'Uni score': 0.2883775912},
#  {'Gender': 3, 'Uni score': -0.6160561524},
#  {'Gender': 2, 'Uni score': 0.4010279315},
#  {'Gender': 2, 'Uni score': 1.2285152577},
#  {'Gender': 1, 'Uni score': 0.3954857239},
#  {'Gender': 3, 'Uni score': 0.0166713517},
#  {'Gender': 1, 'Uni score': -0.0477501237},
#  {'Gender': 1, 'Uni score': 0.9368487783},
#  {'Gender': 0, 'Uni score': 0.5414830511},
#  {'Gender': 2, 'Uni score': 0.9966074833},
#  {'Gender': 0, 'Uni score': 0.4238831606},
#  {'Gender': 1, 'Uni score': 0.7374300216},
#  {'Gender': 3, 'Uni score': 0.5543145052},
#  {'Gender': 2, 'Uni score': 1.0375662236},
#  {'Gender': 3, 'Uni score': 2.5593864477},
#  {'Gender': 0, 'Uni score': 0.5299074971},
#  {'Gender': 2, 'Uni score': 1.1759485921},
#  {'Gender': 0, 'Uni score': 0.2316746682},
#  {'Gender': 3, 'Uni score': 0.2867935986},
#  {'Gender': 1, 'Uni score': 0.4941975029},
#  {'Gender': 3, 'Uni score': 0.8462957335},
#  {'Gender': 1, 'Uni score': 0.2965809891},
#  {'Gender': 2, 'Uni score': 1.0798071831},
#  {'Gender': 0, 'Uni score': 0.2251015727},
#  {'Gender': 3, 'Uni score': 0.785400751},
#  {'Gender': 3, 'Uni score': 1.0988597104},
#  {'Gender': 0, 'Uni score': 0.4729569416},
#  {'Gender': 2, 'Uni score': 0.9086402546},
#  {'Gender': 1, 'Uni score': -0.0830406498},
#  {'Gender': 2, 'Uni score': 0.2276484429},
#  {'Gender': 2, 'Uni score': 0.5136891894},
#  {'Gender': 0, 'Uni score': 0.5372342292},
#  {'Gender': 0, 'Uni score': 0.1749793208},
#  {'Gender': 1, 'Uni score': -0.1129030651},
#  {'Gender': 3, 'Uni score': 1.1937429428},
#  {'Gender': 1, 'Uni score': 0.2984824913},
#  {'Gender': 1, 'Uni score': 0.5349451268},
#  {'Gender': 2, 'Uni score': 1.740847507},
#  {'Gender': 3, 'Uni score': 1.1244466332},
#  {'Gender': 2, 'Uni score': 1.2278713524},
#  {'Gender': 1, 'Uni score': 0.6790208191},
#  {'Gender': 3, 'Uni score': 0.1460573183},
#  {'Gender': 1, 'Uni score': 0.3621790119},
#  {'Gender': 3, 'Uni score': 1.5393797347},
#  {'Gender': 1, 'Uni score': 0.2616582014},
#  {'Gender': 1, 'Uni score': 0.7873527946},
#  {'Gender': 1, 'Uni score': 0.6034523878},
#  {'Gender': 1, 'Uni score': 0.3062463713},
#  {'Gender': 0, 'Uni score': 0.2701560297},
#  {'Gender': 0, 'Uni score': 0.2681224681},
#  {'Gender': 0, 'Uni score': 0.4720923318},
#  {'Gender': 0, 'Uni score': 0.4997823075},
#  {'Gender': 2, 'Uni score': 1.209114409},
#  {'Gender': 3, 'Uni score': 0.7648931773},
#  {'Gender': 0, 'Uni score': 0.4305738829},
#  {'Gender': 0, 'Uni score': 0.1843740574},
#  {'Gender': 1, 'Uni score': 0.4153757422},
#  {'Gender': 0, 'Uni score': 0.3582245706},
#  {'Gender': 1, 'Uni score': 0.4001720404},
#  {'Gender': 0, 'Uni score': 0.3853751912},
#  {'Gender': 2, 'Uni score': 0.9952921694}]

# %%
 """
    - data_set: list of items in dictionary form, which specifies its group and quality
        ex) 
        [{'Gender': 0, 'Uni score': 0.5344585435},
         {'Gender': 2, 'Uni score': 1.0160173543},
         {'Gender': 0, 'Uni score': 0.4573686375},
         {'Gender': 1, 'Uni score': 0.6513702354}]
         
    - attributeNamesAndCategories: attributes that are being used to specify groups in the data_set and its number of categories
        ex)
        {"Gender": 4}
    
    - attributeQuality: the name of the attribute used for quality
        ex)
        "Uni score"
        
    - k: total length of the ranking
    
    - p: array of prbability, that each group could be selected into the ranking
        ex)
        [0.4,0.3,0.2,0.1]
            -> 0.4 for Gender: 0 (Non-protected)
            -> 0.3 for Gender: 1 (Protected)
            -> 0.2 for Gender: 2 (Protected)
            -> 0.1 for Gender: 3 (Protected)
            
    - alpha: Percentage of Type I error        
        
    """

from operator import itemgetter, attrgetter, methodcaller
import itertools
import scipy.stats as stats
import pylab as pl

def get_num_categories(attributeNamesAndCategories):
    num_categories = 1
    for i in attributeNamesAndCategories.items():
        num_categories *= i[1]
    return num_categories    
    
def determineGroups(attributeNamesAndCategories):
    elementSets = []
    groups = []
    for attr, cardinality in attributeNamesAndCategories.items():
        elementSets.append(list(range(0, cardinality)))

    groups = list(itertools.product(*elementSets))
    return groups

def get_minimum_targets(categories, p, alpha, k):
    positions = numpy.array(list(range(k))) + 1;
    minimum_targets = [];
    tau = numpy.zeros(len(categories)-1);

    for i in positions:
        tau_p = multinomial_icdf_continuous(len(p), i, p , alpha, tau)[1:]
        minimum_targets.append(numpy.array(tau_p));
        tau = copy.copy(tau_p);
    return minimum_targets    

def separate_groups(data_set, categories, attributeItems):
    num_categories = len(categories)
    separateByGroups = [[] for _ in range(num_categories)]
    
    for i in data_set:
        categorieList = []
        for j in attributeItems:
            categorieList.append(i[j[0]])
        separateByGroups[categories.index(tuple(categorieList))].append(i)
        categorieList = []
    return separateByGroups    

def plot(data_set,attributeNamesAndCategories, attributeQuality):
    categories = determineGroups(attributeNamesAndCategories)
    attributeItems = attributeNamesAndCategories.items()
    output_ranking_separated = separate_groups(data_set,categories, attributeItems)
    separateQualityByGroups = []
    fig = plt.figure(figsize=(20, 10), dpi=100)
    for i in range(len(categories)):
        separateQualityByGroups.append([quality[attributeQuality] for quality in output_ranking_separated[i]])
        fit = stats.norm.pdf(separateQualityByGroups[i], numpy.mean(separateQualityByGroups[i]), numpy.std(separateQualityByGroups[i])) 
        pl.plot(separateQualityByGroups[i],fit,'-o', label="Group "+`i`)
        pl.hist(separateQualityByGroups[i],normed=True, label="Group "+`i`)
        
    pl.legend(loc='upper right', fontsize='x-large')
    pl.show()    
    
def generate_ranking(data_set, attributeNamesAndCategories, attributeQuality, k, p, alpha):
    index = 0
    categories = determineGroups(attributeNamesAndCategories)
    num_categories = len(categories)
    count = [0 for _ in range(num_categories)];
    ranking = []
    random_choice = ""
    chosen = 0
    num = 1
    swap = 0
    target = ""
    separateByGroups = [[] for _ in range(num_categories)]
    attributeItems = attributeNamesAndCategories.items()
    
    # Separate the groups into each list
    separateByGroups = separate_groups(data_set, categories, attributeItems)
    
    # Sort the items in ascending order of their quality
    for i in range(num_categories):
        separateByGroups[i] = sorted(separateByGroups[i], key=lambda item: item[attributeQuality]) 
    
    minimum_targets = get_minimum_targets(categories, p, alpha, k)
    
    for i in minimum_targets:
        for j in range(len(i)):
            if(i[j] > count[j+1] and chosen == 0):
                item = separateByGroups[j+1].pop()
                ranking.append(item)
                print "chosen", item
                count[j+1] += 1;
                chosen = 1;
                if(any(count[a+1]<i[a] for a in range(len(i)))):
#                     swap = len(rank)-1;
                    print"-------------------------------------------"
#                     while(any(count[a+1]<i[a] for a in range(len(i)))):
#                         target = find_target(least_items, count, races);
#                         if(rank[swap] == races[0]):
#                             rank[swap] = target;
#                             print "swap",rank[swap];
#                             print "count before", count
#                             count[races.index(target)] += 1;
#                             count[0] -= 1;
#                             print "count after",count
#                             print "swap index",swap
#                         swap -= 1;    

                print "Minimum achieved? ", all(count[a+1]>=i[a] for a in range(len(i)))
        if(chosen == 0):
            idx = numpy.random.choice(len(categories),1,p=p)[0]
            random_choice = categories[idx]
            item = separateByGroups[idx].pop()
            print item
            ranking.append(item);
            count[idx] += 1;
        print num, ": ", count, "Minimum Target: ",minimum_targets[num-1];
        print "CDF: ", multinomCDF(num_categories, num, p, [num]+count[1:])
        num = num+1;
        chosen = 0; 
    plot(ranking,attributeNamesAndCategories, attributeQuality)
    return ranking

# %%
test_ranking = generate_ranking(data_set, attribute, 'Uni score',80, [0.4,0.3,0.2,0.1], 0.1)
# Out:
# {'Gender': 2, 'Uni score': 2.2329253232}
# 1 :  [0, 0, 1, 0] Minimum Target:  [ 0.  0.  0.]
# CDF:  0.640189385685
# {'Gender': 0, 'Uni score': 0.7887698602}
# 2 :  [1, 0, 1, 0] Minimum Target:  [ 0.  0.  0.]
# CDF:  0.334713684938
# chosen {'Gender': 3, 'Uni score': 3.6487059175}
# Minimum achieved?  True
# 3 :  [1, 0, 1, 1] Minimum Target:  [ 0.  0.  1.]
# CDF:  0.262889801171
# {'Gender': 3, 'Uni score': 2.5593864477}
# 4 :  [1, 0, 1, 2] Minimum Target:  [ 0.  1.  1.]
# CDF:  0.163281583225
# chosen {'Gender': 2, 'Uni score': 2.1583313833}
# Minimum achieved?  True
# 5 :  [1, 0, 2, 2] Minimum Target:  [ 0.  2.  1.]
# CDF:  0.142894038982
# chosen {'Gender': 1, 'Uni score': 0.9564352348}
# Minimum achieved?  True
# 6 :  [1, 1, 2, 2] Minimum Target:  [ 1.  2.  1.]
# CDF:  0.34492018626
# {'Gender': 3, 'Uni score': 2.3762623133}
# 7 :  [1, 1, 2, 3] Minimum Target:  [ 1.  2.  1.]
# CDF:  0.249808881095
# {'Gender': 2, 'Uni score': 2.0807305529}
# 8 :  [1, 1, 3, 3] Minimum Target:  [ 1.  2.  1.]
# CDF:  0.224916220241
# {'Gender': 0, 'Uni score': 0.6957812452}
# 9 :  [2, 1, 3, 3] Minimum Target:  [ 1.  3.  1.]
# CDF:  0.159164384975
# chosen {'Gender': 1, 'Uni score': 0.9368487783}
# Minimum achieved?  True
# 10 :  [2, 2, 3, 3] Minimum Target:  [ 2.  3.  1.]
# CDF:  0.300819303375
# {'Gender': 1, 'Uni score': 0.9063713513}
# 11 :  [2, 3, 3, 3] Minimum Target:  [ 2.  3.  1.]
# CDF:  0.430084130572
# chosen {'Gender': 2, 'Uni score': 1.9456225999}
# Minimum achieved?  True
# 12 :  [2, 3, 4, 3] Minimum Target:  [ 2.  4.  1.]
# CDF:  0.41827678354
# {'Gender': 2, 'Uni score': 1.8152601943}
# 13 :  [2, 3, 5, 3] Minimum Target:  [ 2.  4.  2.]
# CDF:  0.375726257266
# {'Gender': 0, 'Uni score': 0.6397513191}
# 14 :  [3, 3, 5, 3] Minimum Target:  [ 2.  5.  2.]
# CDF:  0.301020604246
# {'Gender': 1, 'Uni score': 0.8416676898}
# 15 :  [3, 4, 5, 3] Minimum Target:  [ 3.  5.  2.]
# CDF:  0.426796163461
# {'Gender': 2, 'Uni score': 1.7745054487}
# 16 :  [3, 4, 6, 3] Minimum Target:  [ 3.  5.  2.]
# CDF:  0.384427847769
# {'Gender': 1, 'Uni score': 0.825292331}
# 17 :  [3, 5, 6, 3] Minimum Target:  [ 3.  6.  2.]
# CDF:  0.499595532525
# {'Gender': 1, 'Uni score': 0.8102649339}
# 18 :  [3, 6, 6, 3] Minimum Target:  [ 3.  6.  3.]
# CDF:  0.589248875609
# chosen {'Gender': 3, 'Uni score': 2.371649435}
# Minimum achieved?  True
# 19 :  [3, 6, 6, 4] Minimum Target:  [ 3.  6.  4.]
# CDF:  0.574009536504
# {'Gender': 1, 'Uni score': 0.8070704632}
# 20 :  [3, 7, 6, 4] Minimum Target:  [ 4.  6.  4.]
# CDF:  0.650468860144
# {'Gender': 3, 'Uni score': 2.3147588598}
# 21 :  [3, 7, 6, 5] Minimum Target:  [ 4.  6.  4.]
# CDF:  0.61013957445
# {'Gender': 2, 'Uni score': 1.740847507}
# 22 :  [3, 7, 7, 5] Minimum Target:  [ 4.  6.  4.]
# CDF:  0.603475145593
# {'Gender': 0, 'Uni score': 0.6249890982}
# 23 :  [4, 7, 7, 5] Minimum Target:  [ 5.  6.  4.]
# CDF:  0.536805907941
# {'Gender': 1, 'Uni score': 0.8038716912}
# 24 :  [4, 8, 7, 5] Minimum Target:  [ 5.  6.  4.]
# CDF:  0.617756217816
# {'Gender': 0, 'Uni score': 0.6131792943}
# 25 :  [5, 8, 7, 5] Minimum Target:  [ 5.  6.  5.]
# CDF:  0.551983034023
# {'Gender': 1, 'Uni score': 0.8011014761}
# 26 :  [5, 9, 7, 5] Minimum Target:  [ 5.  7.  5.]
# CDF:  0.612847445538
# chosen {'Gender': 2, 'Uni score': 1.7308071018}
# Minimum achieved?  True
# 27 :  [5, 9, 8, 5] Minimum Target:  [ 5.  8.  5.]
# CDF:  0.617652214391
# {'Gender': 0, 'Uni score': 0.5998471958}
# 28 :  [6, 9, 8, 5] Minimum Target:  [ 6.  8.  5.]
# CDF:  0.55601724373
# {'Gender': 1, 'Uni score': 0.7883963507}
# 29 :  [6, 10, 8, 5] Minimum Target:  [ 6.  8.  5.]
# CDF:  0.613562547039
# {'Gender': 0, 'Uni score': 0.5879620438}
# 30 :  [7, 10, 8, 5] Minimum Target:  [ 6.  8.  5.]
# CDF:  0.552985361103
# {'Gender': 1, 'Uni score': 0.7873527946}
# 31 :  [7, 11, 8, 5] Minimum Target:  [ 7.  8.  5.]
# CDF:  0.593907309031
# {'Gender': 1, 'Uni score': 0.7844390139}
# 32 :  [7, 12, 8, 5] Minimum Target:  [ 7.  8.  5.]
# CDF:  0.616753378421
# chosen {'Gender': 3, 'Uni score': 2.0609964935}
# Minimum achieved?  True
# 33 :  [7, 12, 8, 6] Minimum Target:  [ 7.  8.  6.]
# CDF:  0.612391969005
# chosen {'Gender': 2, 'Uni score': 1.6596611711}
# Minimum achieved?  True
# 34 :  [7, 12, 9, 6] Minimum Target:  [ 7.  9.  6.]
# CDF:  0.645031289346
# {'Gender': 0, 'Uni score': 0.5793490205}
# 35 :  [8, 12, 9, 6] Minimum Target:  [ 8.  9.  6.]
# CDF:  0.590794879128
# {'Gender': 2, 'Uni score': 1.607066781}
# 36 :  [8, 12, 10, 6] Minimum Target:  [ 8.  9.  6.]
# CDF:  0.60043422679
# chosen {'Gender': 3, 'Uni score': 1.8843695208}
# Minimum achieved?  True
# 37 :  [8, 12, 10, 7] Minimum Target:  [ 8.  9.  7.]
# CDF:  0.580813823338
# {'Gender': 3, 'Uni score': 1.8331408126}
# 38 :  [8, 12, 10, 8] Minimum Target:  [  8.  10.   7.]
# CDF:  0.543821110225
# {'Gender': 1, 'Uni score': 0.7644476987}
# 39 :  [8, 13, 10, 8] Minimum Target:  [  9.  10.   7.]
# CDF:  0.600176875798
# {'Gender': 0, 'Uni score': 0.5755475355}
# 40 :  [9, 13, 10, 8] Minimum Target:  [  9.  10.   7.]
# CDF:  0.548766631176
# {'Gender': 1, 'Uni score': 0.7374300216}
# 41 :  [9, 14, 10, 8] Minimum Target:  [  9.  10.   7.]
# CDF:  0.592934749952
# {'Gender': 2, 'Uni score': 1.5692812754}
# 42 :  [9, 14, 11, 8] Minimum Target:  [ 10.  10.   7.]
# CDF:  0.615860797737
# {'Gender': 1, 'Uni score': 0.7327512959}
# 43 :  [9, 15, 11, 8] Minimum Target:  [ 10.  10.   7.]
# CDF:  0.657721017852
# {'Gender': 1, 'Uni score': 0.6911401779}
# 44 :  [9, 16, 11, 8] Minimum Target:  [ 10.  10.   8.]
# CDF:  0.685973144102
# {'Gender': 1, 'Uni score': 0.6877514105}
# 45 :  [9, 17, 11, 8] Minimum Target:  [ 10.  11.   8.]
# CDF:  0.701630800652
# {'Gender': 1, 'Uni score': 0.6805179616}
# 46 :  [9, 18, 11, 8] Minimum Target:  [ 11.  11.   8.]
# CDF:  0.706305871456
# {'Gender': 2, 'Uni score': 1.5608242271}
# 47 :  [9, 18, 12, 8] Minimum Target:  [ 11.  11.   8.]
# CDF:  0.749415221702
# chosen {'Gender': 3, 'Uni score': 1.7120243436}
# Minimum achieved?  True
# 48 :  [9, 18, 12, 9] Minimum Target:  [ 11.  11.   9.]
# CDF:  0.736932454724
# {'Gender': 2, 'Uni score': 1.5420521032}
# 49 :  [9, 18, 13, 9] Minimum Target:  [ 11.  12.   9.]
# CDF:  0.765117794776
# {'Gender': 3, 'Uni score': 1.6993016628}
# 50 :  [9, 18, 13, 10] Minimum Target:  [ 12.  12.   9.]
# CDF:  0.74273330823
# {'Gender': 3, 'Uni score': 1.6552765032}
# 51 :  [9, 18, 13, 11] Minimum Target:  [ 12.  12.   9.]
# CDF:  0.711642340485
# {'Gender': 1, 'Uni score': 0.6790208191}
# 52 :  [9, 19, 13, 11] Minimum Target:  [ 12.  12.  10.]
# CDF:  0.736895281169
# {'Gender': 0, 'Uni score': 0.570131607}
# 53 :  [10, 19, 13, 11] Minimum Target:  [ 12.  13.  10.]
# CDF:  0.700544362562
# {'Gender': 1, 'Uni score': 0.6774923993}
# 54 :  [10, 20, 13, 11] Minimum Target:  [ 13.  13.  10.]
# CDF:  0.717953157825
# {'Gender': 2, 'Uni score': 1.528346343}
# 55 :  [10, 20, 14, 11] Minimum Target:  [ 13.  13.  10.]
# CDF:  0.753799134941
# {'Gender': 0, 'Uni score': 0.5414830511}
# 56 :  [11, 20, 14, 11] Minimum Target:  [ 13.  13.  11.]
# CDF:  0.719361008308
# {'Gender': 1, 'Uni score': 0.6749715095}
# 57 :  [11, 21, 14, 11] Minimum Target:  [ 13.  14.  11.]
# CDF:  0.738086803737
# {'Gender': 0, 'Uni score': 0.5390479252}
# 58 :  [12, 21, 14, 11] Minimum Target:  [ 14.  14.  11.]
# CDF:  0.703881396663
# {'Gender': 0, 'Uni score': 0.5372342292}
# 59 :  [13, 21, 14, 11] Minimum Target:  [ 14.  14.  11.]
# CDF:  0.66771883739
# chosen {'Gender': 3, 'Uni score': 1.5733224326}
# Minimum achieved?  True
# 60 :  [13, 21, 14, 12] Minimum Target:  [ 14.  14.  12.]
# CDF:  0.637550703641
# chosen {'Gender': 2, 'Uni score': 1.5137061267}
# Minimum achieved?  True
# 61 :  [13, 21, 15, 12] Minimum Target:  [ 14.  15.  12.]
# CDF:  0.671302748984
# {'Gender': 1, 'Uni score': 0.6738594222}
# 62 :  [13, 22, 15, 12] Minimum Target:  [ 15.  15.  12.]
# CDF:  0.696503785753
# {'Gender': 1, 'Uni score': 0.6673956425}
# 63 :  [13, 23, 15, 12] Minimum Target:  [ 15.  15.  12.]
# CDF:  0.712682649929
# chosen {'Gender': 2, 'Uni score': 1.4140117415}
# Minimum achieved?  True
# 64 :  [13, 23, 16, 12] Minimum Target:  [ 15.  16.  12.]
# CDF:  0.746597049276
# chosen {'Gender': 2, 'Uni score': 1.3983462286}
# Minimum achieved?  True
# 65 :  [13, 23, 17, 12] Minimum Target:  [ 15.  17.  12.]
# CDF:  0.766016898104
# chosen {'Gender': 2, 'Uni score': 1.3643975716}
# Minimum achieved?  True
# 66 :  [13, 23, 18, 12] Minimum Target:  [ 15.  18.  12.]
# CDF:  0.772965901232
# {'Gender': 2, 'Uni score': 1.3569257041}
# 67 :  [13, 23, 19, 12] Minimum Target:  [ 16.  18.  12.]
# CDF:  0.769738988907
# {'Gender': 1, 'Uni score': 0.6549209192}
# 68 :  [13, 24, 19, 12] Minimum Target:  [ 16.  18.  12.]
# CDF:  0.803900737405
# {'Gender': 1, 'Uni score': 0.6513702354}
# 69 :  [13, 25, 19, 12] Minimum Target:  [ 16.  18.  12.]
# CDF:  0.829691615206
# {'Gender': 0, 'Uni score': 0.5350985713}
# 70 :  [14, 25, 19, 12] Minimum Target:  [ 17.  18.  12.]
# CDF:  0.805019525311
# {'Gender': 1, 'Uni score': 0.6509077532}
# 71 :  [14, 26, 19, 12] Minimum Target:  [ 17.  18.  12.]
# CDF:  0.825250858943
# {'Gender': 0, 'Uni score': 0.5344585435}
# 72 :  [15, 26, 19, 12] Minimum Target:  [ 17.  18.  12.]
# CDF:  0.800671962915
# {'Gender': 3, 'Uni score': 1.5393797347}
# 73 :  [15, 26, 19, 13] Minimum Target:  [ 18.  18.  12.]
# CDF:  0.788555409936
# {'Gender': 3, 'Uni score': 1.5378213219}
# 74 :  [15, 26, 19, 14] Minimum Target:  [ 18.  18.  12.]
# CDF:  0.768782235561
# {'Gender': 0, 'Uni score': 0.5299074971}
# 75 :  [16, 26, 19, 14] Minimum Target:  [ 18.  18.  12.]
# CDF:  0.740242629042
# {'Gender': 2, 'Uni score': 1.3513477258}
# 76 :  [16, 26, 20, 14] Minimum Target:  [ 19.  18.  12.]
# CDF:  0.74998789926
# {'Gender': 1, 'Uni score': 0.6207679953}
# 77 :  [16, 27, 20, 14] Minimum Target:  [ 19.  18.  12.]
# CDF:  0.778885298716
# {'Gender': 2, 'Uni score': 1.3349554977}
# 78 :  [16, 27, 21, 14] Minimum Target:  [ 19.  18.  13.]
# CDF:  0.784311025482
# {'Gender': 1, 'Uni score': 0.6155720988}
# 79 :  [16, 28, 21, 14] Minimum Target:  [ 19.  19.  13.]
# CDF:  0.81108365158
# {'Gender': 0, 'Uni score': 0.5285858826}
# 80 :  [17, 28, 21, 14] Minimum Target:  [ 20.  19.  13.]
# CDF:  0.786590355184

# %%
attribute2 = {"Group": 5}   
get_minimum_targets(determineGroups(attribute2), [0.4,0.2,0.2,0.1, 0.1], 0.1, 100)
# Out:
# [array([ 0.,  0.,  0.,  0.]),
#  array([ 0.,  0.,  0.,  0.]),
#  array([ 0.,  0.,  0.,  1.]),
#  array([ 0.,  1.,  0.,  1.]),
#  array([ 0.,  2.,  0.,  1.]),
#  array([ 0.,  2.,  1.,  1.]),
#  array([ 0.,  2.,  1.,  2.]),
#  array([ 1.,  2.,  1.,  2.]),
#  array([ 1.,  2.,  1.,  2.]),
#  array([ 1.,  2.,  1.,  2.]),
#  array([ 1.,  2.,  2.,  2.]),
#  array([ 1.,  3.,  2.,  2.]),
#  array([ 1.,  3.,  2.,  3.]),
#  array([ 1.,  4.,  2.,  3.]),
#  array([ 2.,  4.,  2.,  3.]),
#  array([ 2.,  4.,  2.,  3.]),
#  array([ 2.,  4.,  2.,  3.]),
#  array([ 2.,  4.,  3.,  3.]),
#  array([ 2.,  5.,  3.,  3.]),
#  array([ 2.,  5.,  3.,  4.]),
#  array([ 3.,  5.,  3.,  4.]),
#  array([ 3.,  5.,  3.,  4.]),
#  array([ 3.,  5.,  3.,  4.]),
#  array([ 3.,  6.,  3.,  4.]),
#  array([ 3.,  7.,  3.,  4.]),
#  array([ 3.,  7.,  4.,  4.]),
#  array([ 4.,  7.,  4.,  4.]),
#  array([ 4.,  7.,  4.,  4.]),
#  array([ 4.,  7.,  4.,  4.]),
#  array([ 4.,  7.,  4.,  5.]),
#  array([ 4.,  8.,  4.,  5.]),
#  array([ 4.,  8.,  5.,  5.]),
#  array([ 5.,  8.,  5.,  5.]),
#  array([ 5.,  8.,  5.,  5.]),
#  array([ 5.,  8.,  5.,  5.]),
#  array([ 5.,  9.,  5.,  5.]),
#  array([ 5.,  9.,  5.,  6.]),
#  array([ 6.,  9.,  5.,  6.]),
#  array([ 6.,  9.,  5.,  6.]),
#  array([ 6.,  9.,  5.,  7.]),
#  array([ 6.,  9.,  6.,  7.]),
#  array([ 6.,  9.,  7.,  7.]),
#  array([  6.,  10.,   7.,   7.]),
#  array([  6.,  11.,   7.,   7.]),
#  array([  6.,  11.,   7.,   8.]),
#  array([  6.,  12.,   7.,   8.]),
#  array([  7.,  12.,   7.,   8.]),
#  array([  7.,  12.,   7.,   8.]),
#  array([  7.,  12.,   7.,   8.]),
#  array([  7.,  12.,   7.,   9.]),
#  array([  7.,  13.,   7.,   9.]),
#  array([  8.,  13.,   7.,   9.]),
#  array([  8.,  13.,   7.,   9.]),
#  array([  8.,  13.,   7.,   9.]),
#  array([  8.,  14.,   7.,   9.]),
#  array([  8.,  15.,   7.,   9.]),
#  array([  8.,  15.,   8.,   9.]),
#  array([  9.,  15.,   8.,   9.]),
#  array([  9.,  15.,   8.,   9.]),
#  array([  9.,  15.,   8.,   9.]),
#  array([  9.,  15.,   8.,  10.]),
#  array([  9.,  16.,   8.,  10.]),
#  array([  9.,  16.,   9.,  10.]),
#  array([ 10.,  16.,   9.,  10.]),
#  array([ 10.,  16.,   9.,  10.]),
#  array([ 10.,  16.,   9.,  10.]),
#  array([ 10.,  16.,   9.,  11.]),
#  array([ 11.,  16.,   9.,  11.]),
#  array([ 11.,  16.,   9.,  11.]),
#  array([ 11.,  16.,   9.,  11.]),
#  array([ 11.,  16.,  10.,  11.]),
#  array([ 11.,  17.,  10.,  11.]),
#  array([ 11.,  17.,  11.,  11.]),
#  array([ 11.,  18.,  11.,  11.]),
#  array([ 12.,  18.,  11.,  11.]),
#  array([ 12.,  18.,  11.,  11.]),
#  array([ 12.,  18.,  11.,  11.]),
#  array([ 12.,  18.,  11.,  12.]),
#  array([ 12.,  19.,  11.,  12.]),
#  array([ 13.,  19.,  11.,  12.]),
#  array([ 13.,  19.,  11.,  12.]),
#  array([ 13.,  19.,  11.,  12.]),
#  array([ 13.,  19.,  12.,  12.]),
#  array([ 13.,  20.,  12.,  12.]),
#  array([ 13.,  21.,  12.,  12.]),
#  array([ 14.,  21.,  12.,  12.]),
#  array([ 14.,  21.,  12.,  12.]),
#  array([ 14.,  21.,  12.,  12.]),
#  array([ 14.,  21.,  12.,  13.]),
#  array([ 14.,  22.,  12.,  13.]),
#  array([ 15.,  22.,  12.,  13.]),
#  array([ 15.,  22.,  12.,  13.]),
#  array([ 15.,  22.,  12.,  13.]),
#  array([ 15.,  22.,  12.,  14.]),
#  array([ 15.,  23.,  12.,  14.]),
#  array([ 16.,  23.,  12.,  14.]),
#  array([ 16.,  23.,  12.,  14.]),
#  array([ 16.,  23.,  12.,  14.]),
#  array([ 16.,  24.,  12.,  14.]),
#  array([ 16.,  24.,  13.,  14.])]
